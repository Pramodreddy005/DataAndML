# %%
# Grid Search

# %%
import pandas as pd

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

# %%
data=pd.read_csv(r"C:\Users\pramo\Downloads\spam.csv")
data['category']=data['Category'].apply(lambda x:1 if x=="spam" else 0)

# %%
iris=load_iris()

# %%
#X_train,X_test,y_train,y_test=train_test_split(iris.data,iris.target,test_size=0.2)

# %%
model=RandomForestClassifier()

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [ 10, 15],
    'min_samples_split': [ 5, 10, 15]
}
grid=GridSearchCV(model,param_grid,cv=5,scoring='roc_auc_ovr')

# %%
grid.fit(iris.data,iris.target)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [10, 15],
#                          'min_samples_split': [5, 10, 15],
#                          'n_estimators': [100, 200, 300]},
#              scoring='roc_auc_ovr')

# %%
grid.best_params_,grid.best_score_
# Out:
# ({'max_depth': 10, 'min_samples_split': 15, 'n_estimators': 100},
#  0.9940000000000001)

# %%
#Randomized Search

# %%
rs=RandomizedSearchCV(model,param_grid,n_iter=10,cv=5,scoring='roc_auc_ovr')

# %%
rs.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(),
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25],
#                                         'min_samples_split': [5, 10, 15, 20],
#                                         'n_estimators': [100, 200, 300, 400]},
#                    scoring='roc_auc_ovr')

# %%
pd.DataFrame(rs.cv_results_)[['params','split0_test_score','split1_test_score','split2_test_score','split3_test_score','split4_test_score','mean_test_score']]
# Out:
#                                               params  split0_test_score  \
# 0  {'n_estimators': 100, 'min_samples_split': 15,...                1.0
# 1  {'n_estimators': 300, 'min_samples_split': 15,...                1.0
# 2  {'n_estimators': 100, 'min_samples_split': 5, ...                1.0
# 3  {'n_estimators': 400, 'min_samples_split': 15,...                1.0
# 4  {'n_estimators': 300, 'min_samples_split': 15,...                1.0
# 5  {'n_estimators': 400, 'min_samples_split': 20,...                1.0
# 6  {'n_estimators': 200, 'min_samples_split': 20,...                1.0
# 7  {'n_estimators': 300, 'min_samples_split': 20,...                1.0
# 8  {'n_estimators': 100, 'min_samples_split': 20,...                1.0
# 9  {'n_estimators': 400, 'min_samples_split': 5, ...                1.0
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.989583           0.979167           0.989853                1.0
# ...

# %%
rs.best_params_
# Out:
# {'n_estimators': 400, 'min_samples_split': 15, 'max_depth': 5}
